# %% [markdown]
# # 01. Exercise walkthrough

# %%
# Import libraries 

import pandas as pd
import numpy as np
import os

# %%
# Import Dataset

ords_prods_merge = pd.read_pickle(r'C:\Users\Owner\Desktop\Data Analyst\01-31-2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int32
#  3   orders_day_of_week      int32
#  4   orders_time_of_day      int32
#  5   days_since_prior_order  float32
#  6   df_ords_first_order     bool
#  7   product_id              int32
#  8   add_to_cart_order       int32
#  9   reordered               int32
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  price_range_loc         object
#  15  busiest_days            object
#  16  busiest_period_of_day   object
# dtypes: bool(1), float32(1), float64(1), int32(8), int64(2), object(4)
# memory usage: 3.0+ GB

# %%
# Change datatype to reduce memory usage

ords_prods_merge = ords_prods_merge.astype({"aisle_id": 'int32', "department_id": 'int32', "prices": 'float32'})

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int32
#  3   orders_day_of_week      int32
#  4   orders_time_of_day      int32
#  5   days_since_prior_order  float32
#  6   df_ords_first_order     bool
#  7   product_id              int32
#  8   add_to_cart_order       int32
#  9   reordered               int32
#  10  product_name            object
#  11  aisle_id                int32
#  12  department_id           int32
#  13  prices                  float32
#  14  price_range_loc         object
#  15  busiest_days            object
#  16  busiest_period_of_day   object
# dtypes: bool(1), float32(2), int32(10), object(4)
# memory usage: 2.7+ GB

# %%
# Create a subset

df = ords_prods_merge[:1000000]

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  orders_time_of_day  \
# 0   2539329        1             1                   2                   8
# 1   2398795        1             2                   3                   7
# 2    473747        1             3                   3                  12
# 3   2254736        1             4                   4                   7
# 4    431534        1             5                   4                  15
# 5   3367565        1             6                   2                   7
# 6    550135        1             7                   1                   9
# 7   3108588        1             8                   1                  14
# 8   2295261        1             9                   1                  16
# 9   2550362        1            10                   4                   8
#
#    days_since_prior_order  df_ords_first_order  product_id  add_to_cart_order  \
# ...

# %%
df.shape
# Out:
# (1000000, 17)

# %% [markdown]
# #### Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# #### Aggregating data with agg()

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# same as above without agg

df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# #### Performing multiple aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# #### Aggregating data with transform()

# %%
# Create a loyalty flag using loc

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  orders_time_of_day  \
# 0    2539329        1             1                   2                   8
# 1    2398795        1             2                   3                   7
# 2     473747        1             3                   3                  12
# 3    2254736        1             4                   4                   7
# 4     431534        1             5                   4                  15
# 5    3367565        1             6                   2                   7
# 6     550135        1             7                   1                   9
# 7    3108588        1             8                   1                  14
# 8    2295261        1             9                   1                  16
# 9    2550362        1            10                   4                   8
# 10   2968173       15            15                   1                   9
# ...

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  orders_time_of_day  \
# 0    2539329        1             1                   2                   8
# 1    2398795        1             2                   3                   7
# 2     473747        1             3                   3                  12
# 3    2254736        1             4                   4                   7
# 4     431534        1             5                   4                  15
# 5    3367565        1             6                   2                   7
# 6     550135        1             7                   1                   9
# 7    3108588        1             8                   1                  14
# 8    2295261        1             9                   1                  16
# 9    2550362        1            10                   4                   8
# 10   2968173       15            15                   1                   9
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  orders_time_of_day  \
# 0    2539329        1             1                   2                   8
# 1    2398795        1             2                   3                   7
# 2     473747        1             3                   3                  12
# 3    2254736        1             4                   4                   7
# 4     431534        1             5                   4                  15
# 5    3367565        1             6                   2                   7
# 6     550135        1             7                   1                   9
# 7    3108588        1             8                   1                  14
# 8    2295261        1             9                   1                  16
# 9    2550362        1            10                   4                   8
# 10   2968173       15            15                   1                   9
# ...

# %%
# Deriving columns with loc()

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print frequency

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  orders_time_of_day  \
# 0   2539329        1             1                   2                   8
# 1   2398795        1             2                   3                   7
# 2    473747        1             3                   3                  12
# 3   2254736        1             4                   4                   7
# 4    431534        1             5                   4                  15
#
#    days_since_prior_order  df_ords_first_order  product_id  add_to_cart_order  \
# 0                     NaN                 True         196                  1
# 1                    15.0                False         196                  1
# 2                    21.0                False         196                  1
# 3                    29.0                False         196                  1
# 4                    28.0                False         196                  1
#
# ...

# %% [markdown]
# # 02. Task Questions

# %% [markdown]
# ### Q2: In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Q3: Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %%
# Subset results

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# There isn't a huge difference between the mean values of both dataframes. The values are slightly higher in the subset dataframe except for Department 17 'household'.

# %% [markdown]
# ### Q4: Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# Done during the exercise walkthrough - please see above.

# %% [markdown]
# ### Q5: The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386335  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The prices of products purchased by the loyal customers is less than the new and regular customers. The lower prices can be due to the loyalty programs such as promotions and discount vouchers.

# %% [markdown]
# ### Q6: The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# 1. If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# 2. If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge.groupby('user_id').agg({'prices': ['mean', 'min', 'max']}).head(10)
# Out:
#            prices
#              mean  min        max
# user_id
# 1        6.367797  1.0  14.000000
# 2        7.515897  1.3  14.800000
# 3        8.197727  1.3  14.400000
# 4        8.205556  1.4  14.600000
# 5        9.189189  3.2  14.800000
# 6        8.471429  1.8  19.600000
# 7        7.466990  1.1  23.200001
# 8        8.781632  1.1  14.400000
# 9        7.607895  1.2  19.299999
# 10       8.651049  1.0  24.200001

# %%
# Create a spending column

ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge[['user_id', 'spending_flag', 'spending']].head(10)
# Out:
#    user_id spending_flag  spending
# 0        1   Low spender  6.367797
# 1        1   Low spender  6.367797
# 2        1   Low spender  6.367797
# 3        1   Low spender  6.367797
# 4        1   Low spender  6.367797
# 5        1   Low spender  6.367797
# 6        1   Low spender  6.367797
# 7        1   Low spender  6.367797
# 8        1   Low spender  6.367797
# 9        1   Low spender  6.367797

# %%
# Print frequency

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### Q7: In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# 1. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# 2. If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# 3. If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create order frequency column

ords_prods_merge['order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['order_frequency'] <= 20) & (ords_prods_merge['order_frequency'] > 10 ), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['order_frequency'] <=10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge[['user_id', 'order_frequency', 'frequency_flag']].head()
# Out:
#    user_id  order_frequency         frequency_flag
# 0        1             20.5  Non-frequent customer
# 1        1             20.5  Non-frequent customer
# 2        1             20.5  Non-frequent customer
# 3        1             20.5  Non-frequent customer
# 4        1             20.5  Non-frequent customer

# %%
# Print frequency

ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int32
#  3   orders_day_of_week      int32
#  4   orders_time_of_day      int32
#  5   days_since_prior_order  float32
#  6   df_ords_first_order     bool
#  7   product_id              int32
#  8   add_to_cart_order       int32
#  9   reordered               int32
#  10  product_name            object
#  11  aisle_id                int32
#  12  department_id           int32
#  13  prices                  float32
#  14  price_range_loc         object
#  15  busiest_days            object
#  16  busiest_period_of_day   object
#  17  max_order               int32
#  18  loyalty_flag            object
#  19  spending                float32
#  20  spending_flag           object
# ...

# %% [markdown]
# ### Q9: Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
path = r'C:\Users\Owner\Desktop\Data Analyst\01-31-2022 Instacart Basket Analysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
